# %%
import pandas
data_frame = pandas.read_csv('data/ttc-ridership-1985-2017.csv')
print(data_frame)
# Out:
#                             Unnamed: 0                     Unnamed: 1  \
# 0           TORONTO TRANSIT COMMISSION                            NaN
# 1                ANALYSIS OF RIDERSHIP                            NaN
# 2         1985 TO 2017 ACTUALS (000'S)                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                     FARE MEDIA
# 5                                  WHO                          ADULT
# 6                                  NaN                         TOKENS
# 7                                  NaN                        TICKETS
# 8                                  NaN                       TWO-FARE
# 9                                  NaN           PRESTO - SINGLE RIDE
# 10                                 NaN       PRESTO - SRVM TOKEN RIDE
# 11                                 NaN        PRESTO - SRVM CASH RIDE
# ...
